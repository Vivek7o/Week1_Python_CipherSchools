# %%
age = input("enter your age : ")
age = int(age)
if age >= 14:
    print("line a ")
    print("you are above 14")
else:
    print("sorry  you can't play")
# Out:
# enter your age : 14
# line a
# you are above 14
