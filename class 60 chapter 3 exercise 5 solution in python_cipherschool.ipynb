# %%
# ask a user for name
# Example - vivek kumar
# print count of each words
# output :
     # H : 1
     # a : 2
     # r : 1
     # s : 3
     # h : 3
     # i : 2
     # t : 2
     #   : 1
     # V : 1

# %%
name = input("please enter your name ")
# vivek kumar , len
# name.count("v") , name.count(name[0]) = 2
# name.count("i") , name.count(name[1]) = 1
# name.count("v") , name.count(name[2]) = 1
# name.count("e") , name.count(name[3]) = 1
# name.count("k") , name.count(name[4]) = 2

# output
# name[0] = v : 2
# i : 1
# v : 1
# e : 1
# k : 2
temp_var = "v"
i = 0
while i < len(name):
  if name[i] not in temp_var:
      temp_var += name[i]
      print(f"{name[i]} : {name.count(name[i])}")
  i += 1
