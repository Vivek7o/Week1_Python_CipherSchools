# %%
print("hello\"world\" world")
print('I\'m vivek')
# Out:
# hello"world" world
# I'm vivek

# %%
print("line A\nline B\nvivek c")
# Out:
# line A
# line B
# vivek c

# %%
print("name\tvivek")
# Out:
# name	vivek

# %%
print("this is double backslash\\\\")
# Out:
# this is double backslash\\

# %%
print("hell\blo")
# Out:
# lo
