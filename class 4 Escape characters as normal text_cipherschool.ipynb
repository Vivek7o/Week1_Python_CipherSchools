# %%
# output : Line A \n Line B\
print("Line A \\n Line B")
print("Line B \\t line b")
print("this is 4 double backslash \\\\\\\\")
# output : \" \'
print("\\\" \\\' ")
# Out:
# Line A \n Line B
# Line B \t line b
# this is 4 double backslash \\\\
# \" \'
