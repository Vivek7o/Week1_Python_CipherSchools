# %%
# take two comma separated inputs from user
# 1.) user's name , example - "vivek"
# 2.) a single character , "H"

# output - 2 print lines
# 1.) user's name length
# 2.) count the character that user inputed (bonus : case insensitive count)
