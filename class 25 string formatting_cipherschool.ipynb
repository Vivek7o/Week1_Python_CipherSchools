# %%
name  = "vivek"
age = 18
print("hello " + name + " your age is " + str(age)) #ugly syntax
print("hello {} your age is {} ".format(name, age)) # python 3
# 3.6
print("hello {name} your age is {age}") # clean
# Out:
# hello vivek your age is 18
# hello vivek your age is 18
# hello {name} your age is {age}
