# %%
# string methods part one
name = "vivek"
#1. len() function
length = len(name)
print(length)

# 2. lower() method
print(name.lover())

# 3. upper() method
print(name.upper())

# 4. title() method
print(name.title())

# 5. count() method
print(name.count("vivek"))
