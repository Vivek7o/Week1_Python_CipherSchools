# %%
# string, number
# name = "vivek"
# print(name)
# name = 123
# print(name)

# rule one
# 1number = 4

# letter, _  ..........first letter
# _name = "vivek"

# u1sd = 34

user_one_name = "vivek" # snake case writing
userOneName = "chhotu"  # camel case writing
